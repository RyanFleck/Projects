# %% [markdown]
# # Ryan's Notes on Web Scraping
#
# Utilizing requests, beautifulsoup4, contextlib.
#
# Get deps: `pip3 install requests beautifulsoup4`
#
# **Resources**
# - [Practical intro to web scraping](https://realpython.com/python-web-scraping-practical-introduction/)

# %%
import requests
import contextlib
from bs4 import BeautifulSoup
import pprint
import operator

# %% [markdown]
# Now that we've imported all of our libraries, I need to make a simple request and grab all the HTML for any given URL (webpage address).

# %%
def getPage(url):
    print('Attempting to get HTML/XML from '+url)
    with contextlib.closing(requests.get(url, stream=True)) as resp:
        content_type = resp.headers['Content-Type'].lower()
        print('Content Type: ' + content_type)
        if(resp.status_code == 200 and 'html' in content_type):
            print('Success!')
            return resp.content

        
page_html = getPage('https://ryanfleck.github.io/java')
# Out:
# Attempting to get HTML/XML from https://ryanfleck.github.io/java
# Content Type: text/html; charset=utf-8
# Success!

# %% [markdown]
# Now the HTML is stored in the `page_html` variable. Time to use Beautiful Soup.

# %%
page = BeautifulSoup(page_html, 'html.parser')

for paragraph in page.select('p'):
    print('\n'+paragraph.text)
# Out:
#           RCF2019
#           ⋅
#           Home
#           ⋅
#
#               Invert Page Colors
#
#
#
# Java is a powerful Object-Oriented programming language used to create complex, scalable, reliable enterprise applications. The University of Ottawa uses Java and C to teach Operating Systems, Data Structures and Software Engineering. At MNP LLP, I applied Java to extend client WCMS systems built on Spring. Going forward, I will be using Java at my upcoming Summer internship at IBM. While not my most active manual, I expect this page to see tremendous growth in the next few months.
#
# Java is as good a language as any for learning how to program. Typically I recommend JavaScript as you can create more visual, interactive projects right off the bat, and the developer community is more beginner-friendly and geared towards ‘fun’ projects. With Java, you will be able to write Android Applications, web servers and APIs, desktop applications and even games. Unfortunately, most frameworks for Java are quite complex, and will take more effort to learn and apply when compared to frameworks with simpler goals written in Python, Ruby or JavaScript.
#
# So why learn Java at all?
#
# Java, C#, and other enterprise languages scale well. Large collaborative engineering teams require build systems, unit testing, reliable deployments, frameworks that allow an application to be split into microservices, etc. Learning Java is valuable because companies will hire you to write their trusted language, Java.
#
# How should I get started?
#
# For starters, I’d take CodeCademy’s Learn Java course, ignoring the Pro materials. As a complete beginner, the short course provides reasonable introductions to Control Flow, Object-Oriented Programming and Data Structures in an interactive format far better than YouTube. After completing the Learn Java course, you could read one of the eighty billion Java tomes, or you could begin some projects and Google your way to a few nice-looking Github repositories, using Jenkov’s Tutorials and Java for Beginners as references. I recommend spending some time to learn these supplemental skills:
#
# Work began on Java in 1991, with the goal of creating a “write once, run anywhere” programming language. Heavy focus on stability and security. Java is interpreted, threaded, dynamic, and object-oriented. Source code is compiled to cross-platform bytecode instead of machine language. Unlike Java’s main competitor (at the time,) C++, it only needs to be compiled once; the JVM and core runtime will handle all low-level operations. Memory access is managed in the Java Virtual Machine (JVM). C++ has explicit memory management, which is easier to mishandle.
#
# All code is defined in classes with a .java extension. Commands javac and java compile and run a Java application.
#
# Package is a global, unique string to ensure global unique identifiers. Conventionally, package names are based on the domain name for the project, so docs.oracle.com becomes com.oracle.docs.
#
# Identifiers are names used to encapsulate classes, methods, fields, variables and other names. They must start with an alpha character or underscore, cannot be keywords, and are case sensitive.
#
# Every programming language has slightly different critical syntax rules. Read Java’s official set of code conventions here
#
# Like in C#, memory for objects is allocated automatically. Small objects are stored in faster stack memory. Larger complex objects are stored in heap memory. You can explicitly dereference variables by setting them to null. The Garbage collector gets its own thread. To manage memory:
#
# Small bits of data are stored in variables. When creating a variable, the type of data you are storing can be specified, along with the scope and mutability. Scope determines where the variable can be accessed, and mutability determines when. In most cases, the set of braces you are operating within {} defines the current scope.
#
# After writing these, both variables will be available for use in the current scope. String and int are types, with different associated methods and operations. The integer uses the access modifier private, ensuring the variable cannot be manipulated from outside the class. A static variable or method belongs to the class rather than an instance of an object, and can be invoked without instantiating an instance of an object. It is shared with all instances of a class. final ensures the variable is only initialized once, and is useful for declaring variables that should never be modified. Here are some more modifiers:
#
# Objects are collections of variables and methods. Java has a massive collection of built-in objects available for use, and in addition to these, you can create your own object blueprints, called classes, to group your data and operations together. Objects are the soul of object oriented programming, a paradigm wherein data and procedures are organized into objects, which can interact with each other and be manipulated.
#
# Here, we instantiate a PlanetDestroyer object named deathStar, and use the method zap to destroy a planet. zap is a method that would be written within the PlanetDestroyer class, allowing it to be called here.
#
# ToDo
#
# Multiprocessing enables computers to execute multiple programs across multiple cores simultaneously. In Java, a thread can be implemented by extending the Thread class.
#
# Instantiating an object x that extends Thread and calling x.start() will, unsurprisingly, start the thread. Do not call .run(). See the Jenkov page on threads for alternative implementations using the Runnable interface and anonymous classes.
#
# A Semaphore is a data structure used to address synchronization problems. It can be used in a variety of patterns. Essentially, a semaphore is a number that can be incremented or decremented, but not read, and the value of the semaphore dictates if a thread can continue operating, or must wait. The rules are well defined in the Little Book of Semaphores1 (This numbered list of rules is copied from the text.):
#
# A basic implementation of a semaphore in Java appears as follows, utilizing the built-in Thread library for wait() and notify() to stop and start the threads.
#
# Wait and signal are used in a number of different ways. At this point, it is best to discuss some common patterns to show how semaphores work, and when to apply them. In the subsections below, threads are labeled A, B, C... N, and Semaphores are sx, sy, sz... n or sa, sb, sc when created to deal with a specific thread.
#
# When thread A requires thread B to complete an action before it can continue, it must wait until thread B sends a signal. This ensures that A will never dostuff() before B does.
#
# When thread A and B need to wait for each other, and cannot continue to execute until both finish certain commands. Neither thread can proceed until they reach a given point. To implement this, ensure each thread signals as it arrives, and is placed into the thread queue as count is below zero. The second thread to signal() will call wait() on the first thread, which will call wait() on the second thread, and both can continue to dostuff2(), though the order is not guaranteed.
#
# Short for Mutual Exclusion, ensures only one thread can execute the code in a crital section concurrently. A very large number of threads can operate concurrently using this model, and it is guaranteed that only one will ever doCriticalStuff() at any given moment.
#
# The Multiplex pattern allows a set number of threads to enter a critical path concurrently. This pattern is identical to the Mutex pattern, but the Semaphore is instatiated with value n as count, where n is the thread limit.
#
# An n-threaded generalization of the Rendezvous pattern. All threads will be blocked until the nth thread arrives, and then all can continue simultaneously. The solution incorporates a turnstile where the semaphore is rapidly decremented, then incremented, allowing each thread to pass through after the nth thread arrives. Unfortunately, this barrier pattern can only be used once as the turnstile does not reset itself.
#
# Threads wait before and after executing the critical section, in order to ensure no threads lap the others. Only one barrier is open at a time. When count reaches n, barrierB is locked and barrierA is opened, and vice versa. Locking/unlocking the barriers involves incrementing the semaphore once so it can turnstile when all the threads arrive.
#
# A queue ensures threads of different types proceeed in pairs.
#
# EE stands for Enterprise Edition, whereas the OpenJDK and Java SE implementations are Standard Edition. The difference seems to be in the use case. Java SE is composed of the SE API, including all your favourite data structures, networking, security, database tools, and GUI kit. The EE edition extends SE by including an API and runtime environment for “large-scale, multi-tiered, scalabe, reliable and secure network applications”.2
#
# EE docs can be found at javaee.github.io
#
# EE API docs at javaee.github.io/javaee-spec
#
# Installation help at javaee.github.io/tutorial
#
# Do note that IntelliJ IDEA’s free version does not support Java EE development.
#
# What is a servlet? A small program that responds to web requests - many of them may run simultaneously to handle different types of requests within a web server. A good rundown is provided at JavaTPoint.
#
# A Microservice is simply a function that your request must perform before providing a response, broken out into an independent application. As this article on the Gravitational Blog muses, it’s no different from a typical Rails/Node/Spring application.
#
# Java EE is a maintainable industry standard, with most projects having no external dependencies and thin deployment artifacts.3
#
# This Maven dependency contains the Java EE 8 API, and can be packed into a thin WAR and thrown into a Docker container. The following APIs are common in microservices:
#
# Representational State Transfer utilizes a stateless communication protocol and web standards to present a standardized interface for applications to retrieve data. WildFly utilizes RESTEasy, an implementation of Jax-RX. The following interfaces should be programmed for data access:
#
# Jax-RX provides @ methods for all of the above, and decorators to apply on Java Objects:
#
# Simple Object Access Protocol
#
# WildFly is an application runtime. While learning about Java EE, I found some excellent articles on utilizing version 13-Final, so this is what I’ve used as a base for most of my projects. To install, go to http://wildfly.org/downloads/ and download the Full/Web Distribution package. Unzip this into your program files, and run the add-user script. After a user has been added, you will be able to execute the standalone script and see the HAL user console at http://localhost:9990
#
#
#
# Here is a good article on a small & practical microservice written with Wildfly Swarm.
#
# Spring is a framework for simplifying the construction of enterprise-scale web applications.
#
# Maven is a tool for building and managing Java projects. It plays very well with unit tests and CI systems like Travis CI. A good tutorial for beginners is available here.
#
# ToDo
#
# ToDo
#
# In production, my current internship uses objects and methods from https://dom4j.github.io/ to load and process XML documents. For more information about XML and XPath, please refer to https://ryanfleck.github.io/xml
#
# ToDo
#
# ToDo
#
# See hello_world and get_started guides. IDEs like IntelliJ IDEA and Eclipse have built-in systems for assembling JavaFX GUIs.
#
# Little Book of Semaphores more info needed. ↩
#
# Oracle’s Java EE documentation. ↩
#
# Mario-Leander Remier, Building Web Services with Java EE 8 LinkedIn Learning. ↩
#
# CC BY-SA 4.0 - This work is licensed under a
#
#         Creative Commons Attribution-ShareAlike 4.0 International License.
#
#     You are free to share, redistribute and adapt the material as long as appropriate credit is given, and your contributions are distributed under the same license.
#
#
#
#             Copyright ©2019 Ryan Fleck
#             ⋅ CC BY-SA 4.0

# %% [markdown]
# **Neat.** Now, with our `page` object, we can select HTML elements and read their contents and properties to our heart's content. `Fun.fun.fun()` For starters, I'll write a word count.

# %%
words = {'and': 4, 'apple': 3}

def addWordToDict( word, dictionary ):
    if word not in dictionary.keys():
        dictionary.setdefault(word,1)
    else:
        dictionary[word] += 1

for paragraph in page.select('p'):
    for word in paragraph.text.split():
        addWordToDict(word, words)

# See which words are most frequent.
pprint.pprint(sorted(
    words.items(), 
    key= operator.itemgetter(1), 
    reverse=True))
# Out:
# [('and', 73),
#  ('the', 69),
#  ('to', 51),
#  ('a', 48),
#  ('is', 43),
#  ('of', 32),
#  ('Java', 28),
#  ('be', 24),
#  ('for', 22),
#  ('are', 22),
#  ('in', 21),
#  ('can', 21),
#  ('thread', 15),
#  ('with', 14),
#  ('an', 13),
#  ('will', 12),
#  ('as', 12),
#  ('A', 12),
#  ('The', 11),
#  ('on', 11),
#  ('at', 10),
#  ('that', 10),
#  ('you', 9),
#  ('EE', 9),
#  ('it', 8),
#  ('threads', 8),
#  ('used', 7),
#  ('I', 7),
#  ('this', 7),
#  ('or', 7),
#  ('into', 7),
#  ('your', 7),
#  ('data', 7),
#  ('not', 6),
#  ('more', 6),
#  ('all', 6),
#  ('different', 6),
#  ('most', 5),
#  ('web', 5),
#  ('some', 5),
#  ('only', 5),
#  ('variables', 5),
#  ('objects', 5),
#  ('ToDo', 5),
#  ('semaphore', 5),
#  ('using', 4),
#  ('my', 4),
#  ('good', 4),
#  ('when', 4),
#  ('one', 4),
#  ('run', 4),
#  ('code', 4),
#  ('has', 4),
#  ('must', 4),
#  ('When', 4),
#  ('variable', 4),
#  ('In', 4),
#  ('from', 4),
#  ('ensures', 4),
#  ('object', 4),
#  ('each', 4),
#  ('execute', 4),
#  ('number', 4),
#  ('continue', 4),
#  ('B', 4),
#  ('before', 4),
#  ('until', 4),
#  ('This', 4),
#  ('SE', 4),
#  ('apple', 3),
#  ('⋅', 3),
#  ('programming', 3),
#  ('language', 3),
#  ('create', 3),
#  ('reliable', 3),
#  ('uses', 3),
#  ('systems', 3),
#  ('projects', 3),
#  ('projects.', 3),
#  ('Java,', 3),
#  ('frameworks', 3),
#  ('learn', 3),
#  ('apply', 3),
#  ('written', 3),
#  ('other', 3),
#  ('should', 3),
#  ('After', 3),
#  ('which', 3),
#  ('application.', 3),
#  ('ensure', 3),
#  ('so', 3),
#  ('start', 3),
#  ('cannot', 3),
#  ('critical', 3),
#  ('set', 3),
#  ('stored', 3),
#  ('by', 3),
#  ('thread.', 3),
#  ('To', 3),
#  ('where', 3),
#  ('within', 3),
#  ('current', 3),
#  ('both', 3),
#  ('available', 3),
#  ('use', 3),
#  ('methods', 3),
#  ('class.', 3),
#  ('method', 3),
#  ('It', 3),
#  ('built-in', 3),
#  ('Thread', 3),
#  ('call', 3),
#  ('wait()', 3),
#  ('n', 3),
#  ('wait', 3),
#  ('pattern', 3),
#  ('turnstile', 3),
#  ('no', 3),
#  ('↩', 3),
#  ('4.0', 3),
#  ('Object-Oriented', 2),
#  ('complex,', 2),
#  ('enterprise', 2),
#  ('applications.', 2),
#  ('Data', 2),
#  ('Structures', 2),
#  ('At', 2),
#  ('internship', 2),
#  ('While', 2),
#  ('page', 2),
#  ('see', 2),
#  ('few', 2),
#  ('any', 2),
#  ('learning', 2),
#  ('how', 2),
#  ('recommend', 2),
#  ('interactive', 2),
#  ('able', 2),
#  ('write', 2),
#  ('applications', 2),
#  ('Unfortunately,', 2),
#  ('take', 2),
#  ('C#,', 2),
#  ('unit', 2),
#  ('application', 2),
#  ('For', 2),
#  ('Learn', 2),
#  ('course,', 2),
#  ('As', 2),
#  ('complete', 2),
#  ('provides', 2),
#  ('than', 2),
#  ('could', 2),
#  ('creating', 2),
#  ('once,', 2),
#  ('language.', 2),
#  ('compiled', 2),
#  ('Java’s', 2),
#  ('runtime', 2),
#  ('handle', 2),
#  ('operations.', 2),
#  ('access', 2),
#  ('memory', 2),
#  ('All', 2),
#  ('defined', 2),
#  ('unique', 2),
#  ('names', 2),
#  ('classes,', 2),
#  ('Small', 2),
#  ('memory.', 2),
#  ('You', 2),
#  ('them', 2),
#  ('own', 2),
#  ('determines', 2),
#  ('scope.', 2),
#  ('these,', 2),
#  ('instance', 2),
#  ('never', 2),
#  ('Here', 2),
#  ('Objects', 2),
#  ('called', 2),
#  ('PlanetDestroyer', 2),
#  ('zap', 2),
#  ('allowing', 2),
#  ('here.', 2),
#  ('multiple', 2),
#  ('simultaneously.', 2),
#  ('extends', 2),
#  ('Do', 2),
#  ('See', 2),
#  ('implementations', 2),
#  ('interface', 2),
#  ('Semaphore', 2),
#  ('decremented,', 2),
#  ('but', 2),
#  ('value', 2),
#  ('rules', 2),
#  ('well', 2),
#  ('Little', 2),
#  ('Book', 2),
#  ('implementation', 2),
#  ('utilizing', 2),
#  ('common', 2),
#  ('Semaphores', 2),
#  ('given', 2),
#  ('arrives,', 2),
#  ('queue', 2),
#  ('count', 2),
#  ('second', 2),
#  ('thread,', 2),
#  ('order', 2),
#  ('concurrently.', 2),
#  ('very', 2),
#  ('nth', 2),
#  ('then', 2),
#  ('after', 2),
#  ('barrier', 2),
#  ('once', 2),
#  ('does', 2),
#  ('types', 2),
#  ('API,', 2),
#  ('including', 2),
#  ('API', 2),
#  ('docs', 2),
#  ('found', 2),
#  ('IntelliJ', 2),
#  ('free', 2),
#  ('version', 2),
#  ('small', 2),
#  ('program', 2),
#  ('requests', 2),
#  ('-', 2),
#  ('article', 2),
#  ('thin', 2),
#  ('Maven', 2),
#  ('8', 2),
#  ('following', 2),
#  ('utilizes', 2),
#  ('WildFly', 2),
#  ('about', 2),
#  ('user', 2),
#  ('like', 2),
#  ('XML', 2),
#  ('CC', 2),
#  ('BY-SA', 2),
#  ('under', 2),
#  ('RCF2019', 1),
#  ('Home', 1),
#  ('Invert', 1),
#  ('Page', 1),
#  ('Colors', 1),
#  ('powerful', 1),
#  ('scalable,', 1),
#  ('University', 1),
#  ('Ottawa', 1),
#  ('C', 1),
#  ('teach', 1),
#  ('Operating', 1),
#  ('Systems,', 1),
#  ('Software', 1),
#  ('Engineering.', 1),
#  ('MNP', 1),
#  ('LLP,', 1),
#  ('applied', 1),
#  ('extend', 1),
#  ('client', 1),
#  ('WCMS', 1),
#  ('built', 1),
#  ('Spring.', 1),
#  ('Going', 1),
#  ('forward,', 1),
#  ('upcoming', 1),
#  ('Summer', 1),
#  ('IBM.', 1),
#  ('active', 1),
#  ('manual,', 1),
#  ('expect', 1),
#  ('tremendous', 1),
#  ('growth', 1),
#  ('next', 1),
#  ('months.', 1),
#  ('program.', 1),
#  ('Typically', 1),
#  ('JavaScript', 1),
#  ('visual,', 1),
#  ('right', 1),
#  ('off', 1),
#  ('bat,', 1),
#  ('developer', 1),
#  ('community', 1),
#  ('beginner-friendly', 1),
#  ('geared', 1),
#  ('towards', 1),
#  ('‘fun’', 1),
#  ('With', 1),
#  ('Android', 1),
#  ('Applications,', 1),
#  ('servers', 1),
#  ('APIs,', 1),
#  ('desktop', 1),
#  ('even', 1),
#  ('games.', 1),
#  ('quite', 1),
#  ('effort', 1),
#  ('compared', 1),
#  ('simpler', 1),
#  ('goals', 1),
#  ('Python,', 1),
#  ('Ruby', 1),
#  ('JavaScript.', 1),
#  ('So', 1),
#  ('why', 1),
#  ('all?', 1),
#  ('languages', 1),
#  ('scale', 1),
#  ('well.', 1),
#  ('Large', 1),
#  ('collaborative', 1),
#  ('engineering', 1),
#  ('teams', 1),
#  ('require', 1),
#  ('build', 1),
#  ('systems,', 1),
#  ('testing,', 1),
#  ('deployments,', 1),
#  ('allow', 1),
#  ('split', 1),
#  ('microservices,', 1),
#  ('etc.', 1),
#  ('Learning', 1),
#  ('valuable', 1),
#  ('because', 1),
#  ('companies', 1),
#  ('hire', 1),
#  ('their', 1),
#  ('trusted', 1),
#  ('language,', 1),
#  ('Java.', 1),
#  ('How', 1),
#  ('get', 1),
#  ('started?', 1),
#  ('starters,', 1),
#  ('I’d', 1),
#  ('CodeCademy’s', 1),
#  ('ignoring', 1),
#  ('Pro', 1),
#  ('materials.', 1),
#  ('beginner,', 1),
#  ('short', 1),
#  ('course', 1),
#  ('reasonable', 1),
#  ('introductions', 1),
#  ('Control', 1),
#  ('Flow,', 1),
#  ('Programming', 1),
#  ('format', 1),
#  ('far', 1),
#  ('better', 1),
#  ('YouTube.', 1),
#  ('completing', 1),
#  ('read', 1),
#  ('eighty', 1),
#  ('billion', 1),
#  ('tomes,', 1),
#  ('begin', 1),
#  ('Google', 1),
#  ('way', 1),
#  ('nice-looking', 1),
#  ('Github', 1),
#  ('repositories,', 1),
#  ('Jenkov’s', 1),
#  ('Tutorials', 1),
#  ('Beginners', 1),
#  ('references.', 1),
#  ('spending', 1),
#  ('time', 1),
#  ('these', 1),
#  ('supplemental', 1),
#  ('skills:', 1),
#  ('Work', 1),
#  ('began', 1),
#  ('1991,', 1),
#  ('goal', 1),
#  ('“write', 1),
#  ('anywhere”', 1),
#  ('Heavy', 1),
#  ('focus', 1),
#  ('stability', 1),
#  ('security.', 1),
#  ('interpreted,', 1),
#  ('threaded,', 1),
#  ('dynamic,', 1),
#  ('object-oriented.', 1),
#  ('Source', 1),
#  ('cross-platform', 1),
#  ('bytecode', 1),
#  ('instead', 1),
#  ('machine', 1),
#  ('Unlike', 1),
#  ('main', 1),
#  ('competitor', 1),
#  ('(at', 1),
#  ('time,)', 1),
#  ('C++,', 1),
#  ('needs', 1),
#  ('once;', 1),
#  ('JVM', 1),
#  ('core', 1),
#  ('low-level', 1),
#  ('Memory', 1),
#  ('managed', 1),
#  ('Virtual', 1),
#  ('Machine', 1),
#  ('(JVM).', 1),
#  ('C++', 1),
#  ('explicit', 1),
#  ('management,', 1),
#  ('easier', 1),
#  ('mishandle.', 1),
#  ('classes', 1),
#  ('.java', 1),
#  ('extension.', 1),
#  ('Commands', 1),
#  ('javac', 1),
#  ('java', 1),
#  ('compile', 1),
#  ('Package', 1),
#  ('global,', 1),
#  ('string', 1),
#  ('global', 1),
#  ('identifiers.', 1),
#  ('Conventionally,', 1),
#  ('package', 1),
#  ('based', 1),
#  ('domain', 1),
#  ('name', 1),
#  ('project,', 1),
#  ('docs.oracle.com', 1),
#  ('becomes', 1),
#  ('com.oracle.docs.', 1),
#  ('Identifiers', 1),
#  ('encapsulate', 1),
#  ('methods,', 1),
#  ('fields,', 1),
#  ('names.', 1),
#  ('They', 1),
#  ('alpha', 1),
#  ('character', 1),
#  ('underscore,', 1),
#  ('keywords,', 1),
#  ('case', 1),
#  ('sensitive.', 1),
#  ('Every', 1),
#  ('slightly', 1),
#  ('syntax', 1),
#  ('rules.', 1),
#  ('Read', 1),
#  ('official', 1),
#  ('conventions', 1),
#  ('here', 1),
#  ('Like', 1),
#  ('allocated', 1),
#  ('automatically.', 1),
#  ('faster', 1),
#  ('stack', 1),
#  ('Larger', 1),
#  ('complex', 1),
#  ('heap', 1),
#  ('explicitly', 1),
#  ('dereference', 1),
#  ('setting', 1),
#  ('null.', 1),
#  ('Garbage', 1),
#  ('collector', 1),
#  ('gets', 1),
#  ('its', 1),
#  ('manage', 1),
#  ('memory:', 1),
#  ('bits', 1),
#  ('variables.', 1),
#  ('variable,', 1),
#  ('type', 1),
#  ('storing', 1),
#  ('specified,', 1),
#  ('along', 1),
#  ('scope', 1),
#  ('mutability.', 1),
#  ('Scope', 1),
#  ('accessed,', 1),
#  ('mutability', 1),
#  ('when.', 1),
#  ('cases,', 1),
#  ('braces', 1),
#  ('operating', 1),
#  ('{}', 1),
#  ('defines', 1),
#  ('writing', 1),
#  ('String', 1),
#  ('int', 1),
#  ('types,', 1),
#  ('associated', 1),
#  ('integer', 1),
#  ('modifier', 1),
#  ('private,', 1),
#  ('ensuring', 1),
#  ('manipulated', 1),
#  ('outside', 1),
#  ('static', 1),
#  ('belongs', 1),
#  ('class', 1),
#  ('rather', 1),
#  ('object,', 1),
#  ('invoked', 1),
#  ('without', 1),
#  ('instantiating', 1),
#  ('object.', 1),
#  ('shared', 1),
#  ('instances', 1),
#  ('final', 1),
#  ('initialized', 1),
#  ('useful', 1),
#  ('declaring', 1),
#  ('modified.', 1),
#  ('modifiers:', 1),
#  ('collections', 1),
#  ('methods.', 1),
#  ('massive', 1),
#  ('collection', 1),
#  ('use,', 1),
#  ('addition', 1),
#  ('blueprints,', 1),
#  ('group', 1),
#  ('operations', 1),
#  ('together.', 1),
#  ('soul', 1),
#  ('oriented', 1),
#  ('programming,', 1),
#  ('paradigm', 1),
#  ('wherein', 1),
#  ('procedures', 1),
#  ('organized', 1),
#  ('objects,', 1),
#  ('interact', 1),
#  ('manipulated.', 1),
#  ('Here,', 1),
#  ('we', 1),
#  ('instantiate', 1),
#  ('named', 1),
#  ('deathStar,', 1),
#  ('destroy', 1),
#  ('planet.', 1),
#  ('would', 1),
#  ('class,', 1),
#  ('Multiprocessing', 1),
#  ('enables', 1),
#  ('computers', 1),
#  ('programs', 1),
#  ('across', 1),
#  ('cores', 1),
#  ('implemented', 1),
#  ('extending', 1),
#  ('Instantiating', 1),
#  ('x', 1),
#  ('calling', 1),
#  ('x.start()', 1),
#  ('will,', 1),
#  ('unsurprisingly,', 1),
#  ('.run().', 1),
#  ('Jenkov', 1),
#  ('alternative', 1),
#  ('Runnable', 1),
#  ('anonymous', 1),
#  ('classes.', 1),
#  ('structure', 1),
#  ('address', 1),
#  ('synchronization', 1),
#  ('problems.', 1),
#  ('variety', 1),
#  ('patterns.', 1),
#  ('Essentially,', 1),
#  ('incremented', 1),
#  ('read,', 1),
#  ('dictates', 1),
#  ('if', 1),
#  ('operating,', 1),
#  ('wait.', 1),
#  ('Semaphores1', 1),
#  ('(This', 1),
#  ('numbered', 1),
#  ('list', 1),
#  ('copied', 1),
#  ('text.):', 1),
#  ('basic', 1),
#  ('appears', 1),
#  ('follows,', 1),
#  ('library', 1),
#  ('notify()', 1),
#  ('stop', 1),
#  ('threads.', 1),
#  ('Wait', 1),
#  ('signal', 1),
#  ('ways.', 1),
#  ('point,', 1),
#  ('best', 1),
#  ('discuss', 1),
#  ('patterns', 1),
#  ('show', 1),
#  ('semaphores', 1),
#  ('work,', 1),
#  ('them.', 1),
#  ('subsections', 1),
#  ('below,', 1),
#  ('labeled', 1),
#  ('A,', 1),
#  ('B,', 1),
#  ('C...', 1),
#  ('N,', 1),
#  ('sx,', 1),
#  ('sy,', 1),
#  ('sz...', 1),
#  ('sa,', 1),
#  ('sb,', 1),
#  ('sc', 1),
#  ('created', 1),
#  ('deal', 1),
#  ('specific', 1),
#  ('requires', 1),
#  ('action', 1),
#  ('continue,', 1),
#  ('sends', 1),
#  ('signal.', 1),
#  ('dostuff()', 1),
#  ('does.', 1),
#  ('need', 1),
#  ('other,', 1),
#  ('finish', 1),
#  ('certain', 1),
#  ('commands.', 1),
#  ('Neither', 1),
#  ('proceed', 1),
#  ('they', 1),
#  ('reach', 1),
#  ('point.', 1),
#  ('implement', 1),
#  ('this,', 1),
#  ('signals', 1),
#  ('placed', 1),
#  ('below', 1),
#  ('zero.', 1),
#  ('signal()', 1),
#  ('first', 1),
#  ('dostuff2(),', 1),
#  ('though', 1),
#  ('guaranteed.', 1),
#  ('Short', 1),
#  ('Mutual', 1),
#  ('Exclusion,', 1),
#  ('crital', 1),
#  ('section', 1),
#  ('large', 1),
#  ('operate', 1),
#  ('concurrently', 1),
#  ('model,', 1),
#  ('guaranteed', 1),
#  ('ever', 1),
#  ('doCriticalStuff()', 1),
#  ('moment.', 1),
#  ('Multiplex', 1),
#  ('allows', 1),
#  ('enter', 1),
#  ('path', 1),
#  ('identical', 1),
#  ('Mutex', 1),
#  ('pattern,', 1),
#  ('instatiated', 1),
#  ('count,', 1),
#  ('limit.', 1),
#  ('An', 1),
#  ('n-threaded', 1),
#  ('generalization', 1),
#  ('Rendezvous', 1),
#  ('pattern.', 1),
#  ('blocked', 1),
#  ('solution', 1),
#  ('incorporates', 1),
#  ('rapidly', 1),
#  ('incremented,', 1),
#  ('pass', 1),
#  ('through', 1),
#  ('arrives.', 1),
#  ('reset', 1),
#  ('itself.', 1),
#  ('Threads', 1),
#  ('executing', 1),
#  ('section,', 1),
#  ('lap', 1),
#  ('others.', 1),
#  ('Only', 1),
#  ('open', 1),
#  ('time.', 1),
#  ('reaches', 1),
#  ('n,', 1),
#  ('barrierB', 1),
#  ('locked', 1),
#  ('barrierA', 1),
#  ('opened,', 1),
#  ('vice', 1),
#  ('versa.', 1),
#  ('Locking/unlocking', 1),
#  ('barriers', 1),
#  ('involves', 1),
#  ('incrementing', 1),
#  ('arrive.', 1),
#  ('proceeed', 1),
#  ('pairs.', 1),
#  ('stands', 1),
#  ('Enterprise', 1),
#  ('Edition,', 1),
#  ('whereas', 1),
#  ('OpenJDK', 1),
#  ('Standard', 1),
#  ('Edition.', 1),
#  ('difference', 1),
#  ('seems', 1),
#  ('case.', 1),
#  ('composed', 1),
#  ('favourite', 1),
#  ('structures,', 1),
#  ('networking,', 1),
#  ('security,', 1),
#  ('database', 1),
#  ('tools,', 1),
#  ('GUI', 1),
#  ('kit.', 1),
#  ('edition', 1),
#  ('environment', 1),
#  ('“large-scale,', 1),
#  ('multi-tiered,', 1),
#  ('scalabe,', 1),
#  ('secure', 1),
#  ('network', 1),
#  ('applications”.2', 1),
#  ('javaee.github.io', 1),
#  ('javaee.github.io/javaee-spec', 1),
#  ('Installation', 1),
#  ('help', 1),
#  ('javaee.github.io/tutorial', 1),
#  ('note', 1),
#  ('IDEA’s', 1),
#  ('support', 1),
#  ('development.', 1),
#  ('What', 1),
#  ('servlet?', 1),
#  ('responds', 1),
#  ('many', 1),
#  ('may', 1),
#  ('simultaneously', 1),
#  ('server.', 1),
#  ('rundown', 1),
#  ('provided', 1),
#  ('JavaTPoint.', 1),
#  ('Microservice', 1),
#  ('simply', 1),
#  ('function', 1),
#  ('request', 1),
#  ('perform', 1),
#  ('providing', 1),
#  ('response,', 1),
#  ('broken', 1),
#  ('out', 1),
#  ('independent', 1),
#  ('Gravitational', 1),
#  ('Blog', 1),
#  ('muses,', 1),
#  ('it’s', 1),
#  ('typical', 1),
#  ('Rails/Node/Spring', 1),
#  ('maintainable', 1),
#  ('industry', 1),
#  ('standard,', 1),
#  ('having', 1),
#  ('external', 1),
#  ('dependencies', 1),
#  ('deployment', 1),
#  ('artifacts.3', 1),
#  ('dependency', 1),
#  ('contains', 1),
#  ('packed', 1),
#  ('WAR', 1),
#  ('thrown', 1),
#  ('Docker', 1),
#  ('container.', 1),
#  ('APIs', 1),
#  ('microservices:', 1),
#  ('Representational', 1),
#  ('State', 1),
#  ('Transfer', 1),
#  ('stateless', 1),
#  ('communication', 1),
#  ('protocol', 1),
#  ('standards', 1),
#  ('present', 1),
#  ('standardized', 1),
#  ('retrieve', 1),
#  ('data.', 1),
#  ('RESTEasy,', 1),
#  ('Jax-RX.', 1),
#  ('interfaces', 1),
#  ('programmed', 1),
#  ('access:', 1),
#  ('Jax-RX', 1),
#  ('@', 1),
#  ('above,', 1),
#  ('decorators', 1),
#  ('Objects:', 1),
#  ('Simple', 1),
#  ('Object', 1),
#  ('Access', 1),
#  ('Protocol', 1),
#  ('runtime.', 1),
#  ('EE,', 1),
#  ('excellent', 1),
#  ('articles', 1),
#  ('13-Final,', 1),
#  ('what', 1),
#  ('I’ve', 1),
#  ('base', 1),
#  ('install,', 1),
#  ('go', 1),
#  ('http://wildfly.org/downloads/', 1),
#  ('download', 1),
#  ('Full/Web', 1),
#  ('Distribution', 1),
#  ('package.', 1),
#  ('Unzip', 1),
#  ('files,', 1),
#  ('add-user', 1),
#  ('script.', 1),
#  ('been', 1),
#  ('added,', 1),
#  ('standalone', 1),
#  ('script', 1),
#  ('HAL', 1),
#  ('console', 1),
#  ('http://localhost:9990', 1),
#  ('&', 1),
#  ('practical', 1),
#  ('microservice', 1),
#  ('Wildfly', 1),
#  ('Swarm.', 1),
#  ('Spring', 1),
#  ('framework', 1),
#  ('simplifying', 1),
#  ('construction', 1),
#  ('enterprise-scale', 1),
#  ('tool', 1),
#  ('building', 1),
#  ('managing', 1),
#  ('plays', 1),
#  ('tests', 1),
#  ('CI', 1),
#  ('Travis', 1),
#  ('CI.', 1),
#  ('tutorial', 1),
#  ('beginners', 1),
#  ('production,', 1),
#  ('https://dom4j.github.io/', 1),
#  ('load', 1),
#  ('process', 1),
#  ('documents.', 1),
#  ('information', 1),
#  ('XPath,', 1),
#  ('please', 1),
#  ('refer', 1),
#  ('https://ryanfleck.github.io/xml', 1),
#  ('hello_world', 1),
#  ('get_started', 1),
#  ('guides.', 1),
#  ('IDEs', 1),
#  ('IDEA', 1),
#  ('Eclipse', 1),
#  ('have', 1),
#  ('assembling', 1),
#  ('JavaFX', 1),
#  ('GUIs.', 1),
#  ('info', 1),
#  ('needed.', 1),
#  ('Oracle’s', 1),
#  ('documentation.', 1),
#  ('Mario-Leander', 1),
#  ('Remier,', 1),
#  ('Building', 1),
#  ('Web', 1),
#  ('Services', 1),
#  ('LinkedIn', 1),
#  ('Learning.', 1),
#  ('work', 1),
#  ('licensed', 1),
#  ('Creative', 1),
#  ('Commons', 1),
#  ('Attribution-ShareAlike', 1),
#  ('International', 1),
#  ('License.', 1),
#  ('share,', 1),
#  ('redistribute', 1),
#  ('adapt', 1),
#  ('material', 1),
#  ('long', 1),
#  ('appropriate', 1),
#  ('credit', 1),
#  ('given,', 1),
#  ('contributions', 1),
#  ('distributed', 1),
#  ('same', 1),
#  ('license.', 1),
#  ('Copyright', 1),
#  ('©2019', 1),
#  ('Ryan', 1),
#  ('Fleck', 1)]

# %% [markdown]
# <br />
#
# ## Miscallaneous Python Language Experimentation
# (AKA Stuff I didn't know so I had to write a test to find out.)

# %%
# Is none falsy?
if( None ):
    print('Lol!')
else:
    print('Not lol.')
# Out:
# Not lol.
